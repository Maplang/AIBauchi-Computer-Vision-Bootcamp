# %%
# !pip install ultralytics
import ultralytics
import os
ultralytics.checks()
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/107.7 GB disk)

# %%
# !unzip -q /content/drive/MyDrive/beans_detectord734r764878.zip

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.yaml')  # load a YOLOv8n detection model
results = model.train(data='/content/drive/MyDrive/koboco.yaml', epochs=100, imgsz=640)# train the model
# Out:
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
results_1 = model('/content/test', save = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/6 /content/test/20241005_121725.jpg: 640x480 2 beanss, 422.4ms
# video 2/6 (frame 1/820) /content/test/001.mp4: 640x384 2 beanss, 250.8ms
# video 2/6 (frame 2/820) /content/test/001.mp4: 640x384 1 beans, 256.3ms
# video 2/6 (frame 3/820) /content/test/001.mp4: 640x384 1 beans, 233.3ms
# video 2/6 (frame 4/820) /content/test/001.mp4: 640x384 1 beans, 240.9ms
# ...

# %%
# prompt: download files in runs/detect/track

from google.colab import files
import os

# Specify the folder path
folder_path = '/content/runs/detect/track'

# Get a list of all files in the folder
all_files = os.listdir(folder_path)

# Download each file
for file_name in all_files:
  file_path = os.path.join(folder_path, file_name)
  files.download(file_path)
